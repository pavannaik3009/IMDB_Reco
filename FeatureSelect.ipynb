# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('IMDBcleaned.csv')

# %%
df.head(10)
# Out:
#                                       Movie Name              Director  \
# 0                       The Shawshank Redemption        Frank Darabont
# 1                                  The Godfather  Francis Ford Coppola
# 2                         The Godfather: Part II  Francis Ford Coppola
# 3                                The Dark Knight     Christopher Nolan
# 4                                   12 Angry Men          Sidney Lumet
# 5                               Schindler's List      Steven Spielberg
# 6  The Lord of the Rings: The Return of the King         Peter Jackson
# 7                                   Pulp Fiction     Quentin Tarantino
# 8                 The Good, the Bad and the Ugly          Sergio Leone
# 9                                     Fight Club         David Fincher
#
#    Running Time      Country Language  IMDB Rating      Genre Number of votes  \
# 0           142          USA  English          9.3      Drama       2,161,135
# ...

# %%
print ('Rows     : ', df.shape[0])
print ('Columns  : ', df.shape[1])
print ('\nFeatures : ', df.columns.tolist())
print ('\nMissing values :  ', df.isnull().sum().values.sum())
print ('\nUnique values :  \n', df.nunique())
# Out:
# Rows     :  250
# Columns  :  11
#
# Features :  ['Movie Name', 'Director', 'Running Time', 'Country', 'Language', 'IMDB Rating', 'Genre', 'Number of votes', 'Plot', 'Cast', 'Release Year']
#
# Missing values :   0
#
# Unique values :
#  Movie Name         250
# Director           152
# Running Time       103
# Country             25
# Language            18
# IMDB Rating         13
# Genre               11
# Number of votes    249
# Plot               250
# Cast               247
# Release Year        80
# dtype: int64

# %%
# type of entries, how many null fields
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
# Movie Name         250 non-null object
# Director           250 non-null object
# Running Time       250 non-null int64
# Country            250 non-null object
# Language           250 non-null object
# IMDB Rating        250 non-null float64
# Genre              250 non-null object
# Number of votes    250 non-null object
# Plot               250 non-null object
# Cast               250 non-null object
# Release Year       250 non-null int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 21.6+ KB
# Movie Name         0
# Director           0
# Running Time       0
# Country            0
# Language           0
# IMDB Rating        0
# Genre              0
# Number of votes    0
# Plot               0
# Cast               0
# Release Year       0
# dtype: int64

# %%
df.describe().T #for numeric values
# Out:
#               count       mean        std     min      25%     50%      75%  \
# Running Time  250.0   130.7680  33.164464    45.0   108.25   127.0   147.75
# IMDB Rating   250.0     8.3024   0.228656     8.0     8.10     8.2     8.40
# Release Year  250.0  1987.1040  24.228439  1921.0  1972.00  1994.0  2006.00
#
#                  max
# Running Time   321.0
# IMDB Rating      9.3
# Release Year  2019.0

# %%
df = df[['Movie Name','Director','Cast','Plot','Genre']]
df.index = list(range(1,251))
df
# Out:
#                                             Movie Name              Director  \
# 1                             The Shawshank Redemption        Frank Darabont
# 2                                        The Godfather  Francis Ford Coppola
# 3                               The Godfather: Part II  Francis Ford Coppola
# 4                                      The Dark Knight     Christopher Nolan
# 5                                         12 Angry Men          Sidney Lumet
# 6                                     Schindler's List      Steven Spielberg
# 7        The Lord of the Rings: The Return of the King         Peter Jackson
# 8                                         Pulp Fiction     Quentin Tarantino
# 9                       The Good, the Bad and the Ugly          Sergio Leone
# 10                                          Fight Club         David Fincher
# 11   The Lord of the Rings: The Fellowship of the Ring         Peter Jackson
# ...

# %%
df.to_csv('IMDBfeatures.csv', index=False)
